# %%
import pandas as pd

# %%
pd.read_csv("data_raw/ems20_1st_6months_excerpt.csv")
# Out:
#        CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0            201101264  2020-04-19 10:25:47            INJMIN
# 1            200423766  2020-02-11 19:25:47              CARD
# 2            200434110  2020-02-12 21:36:52               UNC
# 3            201610121  2020-06-09 00:52:30              DRUG
# 4            200034112  2020-01-03 20:44:05              DRUG
# ...                ...                  ...               ...
# 13112        200393407  2020-02-08 19:49:33            DIFFBR
# 13113        200034618  2020-01-03 22:51:33            INJURY
# 13114        200424355  2020-02-11 21:51:09              SICK
# 13115        201742708  2020-06-22 15:57:44            MVAINJ
# 13116        200865674  2020-03-26 19:33:19            DIFFFC
#
#        INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                                7          INJMIN                          7
# ...

# %%
ems2020_excerpt_df = pd.read_csv("data_raw/ems20_1st_6months_excerpt.csv")

# %%
type(ems2020_excerpt_df)
# Out:
# pandas.core.frame.DataFrame

# %%
ems2020_excerpt_df.head(10)
# Out:
#    CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0        201101264  2020-04-19 10:25:47            INJMIN
# 1        200423766  2020-02-11 19:25:47              CARD
# 2        200434110  2020-02-12 21:36:52               UNC
# 3        201610121  2020-06-09 00:52:30              DRUG
# 4        200034112  2020-01-03 20:44:05              DRUG
# 5        200530247  2020-02-22 01:26:18              DRUG
# 6        200543279  2020-02-23 19:08:27               UNC
# 7        201471743  2020-05-26 12:45:46            INJURY
# 8        201180116  2020-04-27 00:57:48               EDP
# 9        200572739  2020-02-26 15:15:25            CARDBR
#
#    INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                            7          INJMIN                          7
# 1                            3            SICK                          6
# 2                            2             UNC                          2
# ...

# %%
ems2020_excerpt_df.tail(5)
# Out:
#        CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 13112        200393407  2020-02-08 19:49:33            DIFFBR
# 13113        200034618  2020-01-03 22:51:33            INJURY
# 13114        200424355  2020-02-11 21:51:09              SICK
# 13115        201742708  2020-06-22 15:57:44            MVAINJ
# 13116        200865674  2020-03-26 19:33:19            DIFFFC
#
#        INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 13112                            2          DIFFBR                          2
# 13113                            5          INJURY                          5
# 13114                            6            SICK                          6
# 13115                            4          MVAINJ                          4
# 13116                            2          DIFFFC                          2
#
#       FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# ...

# %%
ems2020_excerpt_df.sample(20)
# Out:
#        CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 12247        200713270  2020-03-11 17:36:29            MVAINJ
# 7531         200042221  2020-01-04 13:55:42            CARDBR
# 4016         201633333  2020-06-11 20:27:34              EDPC
# 3320         201790020  2020-06-27 00:04:40            UNKNOW
# 12144        201571302  2020-06-05 10:34:01              SICK
# 1668         200613371  2020-03-01 19:17:17            DIFFBR
# 9773         201771436  2020-06-25 11:08:46            CARDBR
# 12127        200640804  2020-03-04 07:32:21              SICK
# 11355        200530779  2020-02-22 05:09:45              SICK
# 2496         200782490  2020-03-18 14:16:56            SICMIN
# 3222         200852131  2020-03-25 10:44:19            INJURY
# 272          201172029  2020-04-26 15:39:58            ARREST
# 94           200973083  2020-04-06 12:43:22            SICKFC
# 3202         200243877  2020-01-24 19:31:56              EDPC
# ...

# %%
ems2020_excerpt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13117 entries, 0 to 13116
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   CAD_INCIDENT_ID                 13117 non-null  int64
#  1   INCIDENT_DATETIME               13117 non-null  object
#  2   INITIAL_CALL_TYPE               13117 non-null  object
#  3   INITIAL_SEVERITY_LEVEL_CODE     13117 non-null  int64
#  4   FINAL_CALL_TYPE                 13117 non-null  object
#  5   FINAL_SEVERITY_LEVEL_CODE       13117 non-null  int64
#  6   FIRST_ASSIGNMENT_DATETIME       13010 non-null  object
#  7   VALID_DISPATCH_RSPNS_TIME_INDC  13117 non-null  object
#  8   DISPATCH_RESPONSE_SECONDS_QY    13117 non-null  int64
#  9   FIRST_ACTIVATION_DATETIME       12988 non-null  object
#  10  FIRST_ON_SCENE_DATETIME         12533 non-null  object
#  11  VALID_INCIDENT_RSPNS_TIME_INDC  13117 non-null  object
# ...

# %%
ems2020_excerpt_df.head(7)
# Out:
#    CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0        201101264  2020-04-19 10:25:47            INJMIN
# 1        200423766  2020-02-11 19:25:47              CARD
# 2        200434110  2020-02-12 21:36:52               UNC
# 3        201610121  2020-06-09 00:52:30              DRUG
# 4        200034112  2020-01-03 20:44:05              DRUG
# 5        200530247  2020-02-22 01:26:18              DRUG
# 6        200543279  2020-02-23 19:08:27               UNC
#
#    INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                            7          INJMIN                          7
# 1                            3            SICK                          6
# 2                            2             UNC                          2
# 3                            4            DRUG                          4
# 4                            4            DRUG                          4
# ...

# %%
ems2020_excerpt_df.sample(10)
# Out:
#       CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 7215        201742577  2020-06-22 15:20:30            UNKNOW
# 9656        201190890  2020-04-28 09:03:07            STATEP
# 6682        201220389  2020-05-01 03:42:02               EDP
# 453         200862985  2020-03-26 12:12:39             ANAPH
# 3393        200473669  2020-02-16 21:05:17               EDP
# 877         200010171  2020-01-01 00:33:34              PD13
# 6300        201663060  2020-06-14 20:09:06            ARREST
# 3051        201771223  2020-06-25 09:57:31              DRUG
# 6692        200453924  2020-02-14 21:03:48            INJURY
# 5757        200334155  2020-02-02 23:07:44            ARREST
#
#       INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 7215                            4          UNKNOW                          4
# 9656                            2          STATEP                          2
# ...

# %%
ems2020_excerpt_df.tail(6)
# Out:
#        CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 13111        200870168  2020-03-27 00:42:59            INJURY
# 13112        200393407  2020-02-08 19:49:33            DIFFBR
# 13113        200034618  2020-01-03 22:51:33            INJURY
# 13114        200424355  2020-02-11 21:51:09              SICK
# 13115        201742708  2020-06-22 15:57:44            MVAINJ
# 13116        200865674  2020-03-26 19:33:19            DIFFFC
#
#        INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 13111                            5          INJURY                          5
# 13112                            2          DIFFBR                          2
# 13113                            5          INJURY                          5
# 13114                            6            SICK                          6
# 13115                            4          MVAINJ                          4
# ...

# %%
fianlcall_2245 = ems2020_excerpt_df["FINAL_CALL_TYPE"][2244]
fianlcall_2245
# Out:
# 'STAB'

# %%
cbp_df = pd.read_excel("data_raw/multi-data.xlsx", sheet_name = "CBP")
cbp_df
# Out:
#                 Unnamed: 0           Unnamed: 1 Unnamed: 2   Unnamed: 3  \
# 0                      NaN                  NaN        NaN          NaN
# 1                      NaN                  NaN        NaN          NaN
# 2                      NaN                  NaN        NaN          NaN
# 3                      NaN                  NaN        NaN          NaN
# 4                      NaN                  NaN        NaN          NaN
# ...                    ...                  ...        ...          ...
# 95722  2018-06-02 13:00:00  2018-06-04 09:05:00  44.066667  15-18 years
# 95723  2018-06-02 13:00:00  2018-06-04 09:05:00  44.066667  12-14 years
# 95724  2018-06-02 13:05:00  2018-06-05 23:35:00  82.483333    6-8 years
# 95725  2018-06-02 13:05:00  2018-06-04 00:54:00       35.8  15-18 years
# 95726  2018-06-02 13:20:00  2018-06-06 07:27:00       90.1    6-8 years
#
#       Unnamed: 4   Unnamed: 5 Unnamed: 6  Unnamed: 7 Unnamed: 8
# ...

# %%
cbp_df1 = pd.read_excel("data_raw/multi-data.xlsx", sheet_name = "CBP", skiprows = 6)
cbp_df1
# Out:
#                   date_in            date_out  hours_in_custody    age_group  \
# 0     2017-01-20 00:10:00 2017-01-20 10:08:00          9.950000    6-8 years
# 1     2017-01-20 00:15:00 2017-01-24 17:30:00        113.233333    3-5 years
# 2     2017-01-20 00:22:00 2017-01-24 17:47:00        113.416667    3-5 years
# 3     2017-01-20 00:30:00 2017-01-21 06:35:00         30.083333  12-14 years
# 4     2017-01-20 00:30:00 2017-01-21 13:03:00         36.533333    3-5 years
# ...                   ...                 ...               ...          ...
# 95716 2018-06-02 13:00:00 2018-06-04 09:05:00         44.066667  15-18 years
# 95717 2018-06-02 13:00:00 2018-06-04 09:05:00         44.066667  12-14 years
# 95718 2018-06-02 13:05:00 2018-06-05 23:35:00         82.483333    6-8 years
# 95719 2018-06-02 13:05:00 2018-06-04 00:54:00         35.800000  15-18 years
# 95720 2018-06-02 13:20:00 2018-06-06 07:27:00         90.100000    6-8 years
#
# ...

# %%
cbp_df1.head(15)
# Out:
#                date_in            date_out  hours_in_custody     age_group  \
# 0  2017-01-20 00:10:00 2017-01-20 10:08:00          9.950000     6-8 years
# 1  2017-01-20 00:15:00 2017-01-24 17:30:00        113.233333     3-5 years
# 2  2017-01-20 00:22:00 2017-01-24 17:47:00        113.416667     3-5 years
# 3  2017-01-20 00:30:00 2017-01-21 06:35:00         30.083333   12-14 years
# 4  2017-01-20 00:30:00 2017-01-21 13:03:00         36.533333     3-5 years
# 5  2017-01-20 00:30:00 2017-01-21 15:30:00         38.983333  Under 1 year
# 6  2017-01-20 00:35:00 2017-01-21 11:52:00         35.266667     6-8 years
# 7  2017-01-20 00:35:00 2017-01-20 15:14:00         14.633333     6-8 years
# 8  2017-01-20 00:35:00 2017-01-21 11:52:00         35.266667     3-5 years
# 9  2017-01-20 00:35:00 2017-01-21 11:52:00         35.266667    9-11 years
# 10 2017-01-20 00:45:00 2017-01-20 13:15:00         12.500000   15-18 years
# ...

# %%
cbp_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95721 entries, 0 to 95720
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date_in           95721 non-null  datetime64[ns]
#  1   date_out          95223 non-null  datetime64[ns]
#  2   hours_in_custody  95506 non-null  float64
#  3   age_group         95716 non-null  object
#  4   gender            95721 non-null  object
#  5   citizenship       95721 non-null  object
#  6   border            95721 non-null  object
#  7   sector            95721 non-null  object
#  8   field_office      0 non-null      float64
# dtypes: datetime64[ns](2), float64(2), object(5)
# memory usage: 6.6+ MB

# %%
cbp_df1.tail(3)
# Out:
#                   date_in            date_out  hours_in_custody    age_group  \
# 95718 2018-06-02 13:05:00 2018-06-05 23:35:00         82.483333    6-8 years
# 95719 2018-06-02 13:05:00 2018-06-04 00:54:00         35.800000  15-18 years
# 95720 2018-06-02 13:20:00 2018-06-06 07:27:00         90.100000    6-8 years
#
#        gender citizenship border      sector  field_office
# 95718  Female   GUATEMALA    SBO  (b)(7)(E )           NaN
# 95719    Male   GUATEMALA    SBO  (b)(7)(E )           NaN
# 95720    Male   GUATEMALA    SBO  (b)(7)(E )           NaN

# %%
cbp_df1.sample(20)
# Out:
#                   date_in            date_out  hours_in_custody     age_group  \
# 80190 2018-04-21 00:15:00 2018-04-25 14:01:00        109.750000  Under 1 year
# 93299 2018-05-26 21:25:00 2018-05-29 13:30:00         64.066667   15-18 years
# 12682 2017-05-29 22:45:00 2017-05-30 13:12:00         14.433333   15-18 years
# 10044 2017-04-24 13:45:00 2017-04-25 14:10:00         24.150000     6-8 years
# 19136 2017-07-23 08:45:00 2017-07-24 11:57:00         27.183333   15-18 years
# 89812 2018-05-18 14:50:00 2018-05-20 17:03:00         50.200000   12-14 years
# 11084 2017-05-09 17:26:00 2017-05-10 08:06:00         14.650000   15-18 years
# 26559 2017-09-04 18:46:00 2017-09-06 00:41:00         29.900000   15-18 years
# 22299 2017-08-12 16:55:00 2017-08-14 15:27:00         46.500000     6-8 years
# 28400 2017-09-14 11:10:00 2017-09-17 14:24:00         75.216667    9-11 years
# 51410 2017-12-23 22:01:00 2017-12-25 10:33:00         36.516667   15-18 years
# ...

# %%
cbp_df1["hours_in_custody"]
# Out:
# 0          9.950000
# 1        113.233333
# 2        113.416667
# 3         30.083333
# 4         36.533333
#             ...
# 95716     44.066667
# 95717     44.066667
# 95718     82.483333
# 95719     35.800000
# 95720     90.100000
# Name: hours_in_custody, Length: 95721, dtype: float64

# %%
cbp_df1["hours_in_custody"].unique()
# Out:
# array([  9.95      , 113.23333333, 113.41666667, ..., 100.18333333,
#        126.28333333, 118.66666667])

# %%
cbp_df1["hours_in_custody"].nunique()
# Out:
# 8293

# %%
hours_in_custody_8 = cbp_df1["hours_in_custody"][7]
hours_in_custody_8
# Out:
# 14.6333333333333
